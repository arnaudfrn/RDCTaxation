# %%
import os 

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from tensorflow.keras.models import Model
from tensorflow.keras.applications import vgg16
from sklearn.datasets import make_blobs
from PIL import Image
import cv2

# %%
def image_resize(path):    
    path = path

    files = []
    # r=root, d=directories, f = files
    for r, d, f in os.walk(path):
        for file in f:
            if '.jpg' in file:
                files.append(os.path.join(r, file))

    for f in files:
        #print(f)
        foo = Image.open(f)
        foo = foo.resize((200,150),Image.ANTIALIAS)
        foo.save(f,optimize=True,quality=95)

# %%
#image_resize(path = "/Users/arnaud/Desktop/Kananga/House Pictures Example/")

# %%
img = cv2.imread("/Users/arnaud/Desktop/Kananga/House Pictures Example/1530690485787.jpg")

Z = img.reshape((-1,3))
# convert to np.float32
Z = np.float32(Z)

# define criteria, number of clusters(K) and apply kmeans()
criteria = (cv2.TERM_CRITERIA_EPS + cv2.TERM_CRITERIA_MAX_ITER, 10, 1.0)
K = 8
ret,label,center=cv2.kmeans(Z,K,None,criteria,10,cv2.KMEANS_RANDOM_CENTERS)
# Now convert back into uint8, and make original image
center = np.uint8(center)
res = center[label.flatten()]
res2 = res.reshape((img.shape))

cv2.imshow('res2',res2)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img = cv2.imread("/Users/arnaud/Desktop/Kananga/House Pictures Example/1530690485787.jpg")

Z = img.reshape((-1,3))
# convert to np.float32
Z = np.float32(Z)

# %%
pd.DataFrame(Z)
# Out:
#            0      1      2
# 0      250.0  251.0  249.0
# 1      250.0  251.0  249.0
# 2      250.0  251.0  249.0
# 3      250.0  251.0  249.0
# 4      249.0  249.0  249.0
# 5      251.0  251.0  251.0
# 6      252.0  250.0  250.0
# 7      239.0  237.0  237.0
# 8      201.0  199.0  199.0
# 9      158.0  156.0  156.0
# 10     198.0  195.0  197.0
# 11     211.0  208.0  210.0
# 12     116.0  113.0  115.0
# 13     117.0  114.0  116.0
# 14     119.0  113.0  118.0
# 15     104.0  100.0  105.0
# 16     111.0  107.0  112.0
# 17     120.0  119.0  123.0
# 18     128.0  127.0  131.0
# 19     139.0  138.0  142.0
# 20     135.0  134.0  138.0
# 21     135.0  134.0  138.0
# 22     172.0  174.0  175.0
# 23     250.0  252.0  253.0
# 24     248.0  247.0  249.0
# 25     245.0  244.0  246.0
# 26     240.0  240.0  240.0
# 27     249.0  249.0  249.0
# 28     215.0  213.0  213.0
# 29     182.0  180.0  180.0
# ...      ...    ...    ...
# 29970   60.0   57.0   29.0
# 29971   62.0   60.0   30.0
# 29972   62.0   62.0   32.0
# 29973   63.0   65.0   35.0
# 29974   64.0   65.0   39.0
# 29975   60.0   63.0   37.0
# 29976   60.0   61.0   35.0
# 29977   61.0   65.0   36.0
# 29978   58.0   61.0   36.0
# 29979   58.0   61.0   39.0
# 29980   63.0   68.0   47.0
# 29981   66.0   69.0   53.0
# 29982   67.0   72.0   57.0
# 29983   69.0   73.0   61.0
# 29984   84.0   89.0   80.0
# 29985   87.0   91.0   85.0
# 29986   85.0   89.0   84.0
# 29987   84.0   89.0   88.0
# 29988   86.0   90.0   91.0
# 29989   82.0   87.0   90.0
# 29990   79.0   85.0   92.0
# 29991   77.0   83.0   88.0
# 29992   78.0   82.0   87.0
# 29993   77.0   82.0   85.0
# 29994   76.0   80.0   85.0
# 29995   76.0   80.0   85.0
# 29996   75.0   81.0   86.0
# 29997   75.0   81.0   86.0
# 29998   75.0   81.0   88.0
# 29999   75.0   81.0   88.0
#
# [30000 rows x 3 columns]

# %%
nnet = vgg16.VGG16(include_top=True, weights='imagenet', input_tensor=None, input_shape=None, pooling=None, classes=1000)
# Out:
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.1/vgg16_weights_tf_dim_ordering_tf_kernels.h5
# 553467904/553467096 [==============================] - 1441s 3us/step
